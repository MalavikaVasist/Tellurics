# %%
import sys
from telfit import Modeler

import numpy as np
import os 
import matplotlib.pyplot as plt
from scipy.stats import qmc
import h5py

from pathlib import Path

import torch 

import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 12
#       8 import h5py
#      10 from pathlib import Path
# ---> 12 import torch
#      14 import time
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## Testing simple model

# %%
# Set the start and end wavelength, in nm
wavestart = 500.0
waveend = 1800.0

# Make the model
modeler = Modeler(nmolecules=12)
model = modeler.MakeModel(humidity=50.0,
                          lowfreq=1e7/waveend,
                          highfreq=1e7/wavestart, 
                          )
# Out:
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 15.07user 1.82system 0:17.04elapsed 99%CPU (0avgtext+0avgdata 7808maxresident)k
# 0inputs+2071176outputs (0major+1103minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 6.96user 1.53system 0:08.56elapsed 99%CPU (0avgtext+0avgdata 7552maxresident)k
# 0inputs+1511992outputs (0major+1105minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 3.08user 1.29system 0:04.40elapsed 99%CPU (0avgtext+0avgdata 7808maxresident)k
# 0inputs+1150968outputs (0major+1103minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 2.43user 1.25system 0:03.71elapsed 99%CPU (0avgtext+0avgdata 7808maxresident)k
# 0inputs+990792outputs (0major+1101minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 1.81user 1.25system 0:03.13elapsed 98%CPU (0avgtext+0avgdata 7680maxresident)k
# 0inputs+897440outputs (0major+1101minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 1.62user 1.15system 0:02.86elapsed 97%CPU (0avgtext+0avgdata 7552maxresident)k
# 0inputs+775600outputs (0major+1100minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 1.37user 1.13system 0:02.53elapsed 99%CPU (0avgtext+0avgdata 7680maxresident)k
# 0inputs+708136outputs (0major+1092minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 0.59user 0.89system 0:01.50elapsed 99%CPU (0avgtext+0avgdata 7552maxresident)k
# 0inputs+151256outputs (0major+1082minor)pagefaults 0swaps

# %%
plt.plot(model.x, model.y)
plt.show()

# %% [markdown]
# ## Using all model parameters

# %%
# Wavelength range in nm
wavestart = 500.0   # nm
waveend = 1800.0    # nm

modeler = Modeler(nmolecules=12)

model = modeler.MakeModel(
    # Atmospheric conditions at telescope
    pressure=795.0,         # hPa
    temperature=283.0,      # Kelvin
    humidity=50.0,          # percent relative humidity
    angle=45.0,             # zenith distance (degrees); airmass = sec(angle)

    # Spectral range (wavenumber, cm^-1)
    lowfreq=1e7 / waveend,  # cm^-1  (from nm)
    highfreq=1e7 / wavestart,  # cm^-1  (from nm)

    # Molecular mixing ratios (ppmv)
    co2=368.5,
    o3=0.039,
    n2o=0.32,
    co=0.14,
    ch4=1.8,
    o2=210000.0,
    no=1.1e-19,
    so2=0.0001,
    no2=0.0001,
    nh3=0.0001,
    hno3=0.00056,

    # Observatory location
    lat=30.6,               # degrees
    alt=2.1,                # km above sea level

    # Optional output processing
    wavegrid=None,          # 1D np array to resample onto (or None)
    resolution=None,        # R = lam/dlam for Gaussian convolution (or None)
    save=False,             # save the generated model to disk
    libfile=None,           # filename to log saved model path (if save=True)
    vac2air=True,           # convert vacuum -> air wavelengths
)

# model.x = wavelength (nm), model.y = fractional transmission
print(f'Wavelength range: {model.x.min():.1f} - {model.x.max():.1f} nm')
print(f'Number of points: {len(model.x)}')
# Out:
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 11.76user 1.54system 0:13.52elapsed 98%CPU (0avgtext+0avgdata 7424maxresident)k
# 0inputs+2071064outputs (0major+1102minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 7.16user 1.63system 0:09.07elapsed 97%CPU (0avgtext+0avgdata 7808maxresident)k
# 0inputs+1511984outputs (0major+1103minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 2.95user 1.37system 0:04.37elapsed 99%CPU (0avgtext+0avgdata 7808maxresident)k
# 0inputs+1151000outputs (0major+1101minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 2.46user 1.27system 0:03.75elapsed 99%CPU (0avgtext+0avgdata 7680maxresident)k
# 0inputs+990768outputs (0major+1105minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 1.90user 1.20system 0:03.21elapsed 96%CPU (0avgtext+0avgdata 7552maxresident)k
# 0inputs+897512outputs (0major+1102minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 1.62user 1.14system 0:02.80elapsed 98%CPU (0avgtext+0avgdata 7552maxresident)k
# 0inputs+775568outputs (0major+1099minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 1.51user 1.14system 0:02.72elapsed 97%CPU (0avgtext+0avgdata 7552maxresident)k
# 0inputs+708152outputs (0major+1091minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 0.56user 0.83system 0:01.41elapsed 98%CPU (0avgtext+0avgdata 7680maxresident)k
# 0inputs+151296outputs (0major+1085minor)pagefaults 0swaps
# Wavelength range: 499.9 - 1799.5 nm
# Number of points: 5869040

# %%
plt.figure(figsize=(12, 4))
plt.plot(model.x, model.y, lw=0.5)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Transmission')
plt.title('Telluric model (full parameter set)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Generate a training set

# %%
os.environ["TELLURICMODELING"] = os.environ["HOME"]+ "/Documents/Tellurics/TelFit/telluric_templates/"

# %%
n_samples = 10  

# Parameter ranges: [low, high]
param_ranges = {
    'pressure':    (750, 850),         # hPa
    'temperature': (270, 300),         # Kelvin
    'humidity':    (10, 90),           # percent
    # 'co2':         (350, 450),         # ppmv
    # 'o3':          (0.02, 0.08),       # ppmv
    # 'n2o':         (0.30, 0.35),       # ppmv
    # 'co':          (0.05, 0.30),       # ppmv
    # 'ch4':         (1.7, 2.1),         # ppmv
    # 'o2':          (209000, 210000),   # ppmv
    # 'no':          (1e-5, 1e-3),       # ppmv
    # 'so2':         (1e-5, 1e-3),       # ppmv
    # 'no2':         (1e-5, 1e-3),       # ppmv
    # 'nh3':         (1e-5, 1e-3),       # ppmv
    # 'hno3':        (1e-4, 1e-3),       # ppmv
}

# Fixed parameters
fixed_params = {
    'lat': 30.6,
    'alt': 2.1,
    'angle': 60,
}

param_names = list(param_ranges.keys())
bounds_low = [v[0] for v in param_ranges.values()]
bounds_high = [v[1] for v in param_ranges.values()]

# Latin Hypercube Sampling
sampler = qmc.LatinHypercube(d=len(param_names), seed=42)
samples_unit = sampler.random(n=n_samples)  # values in [0, 1]
samples = qmc.scale(samples_unit, bounds_low, bounds_high)  # scaled to real ranges

print(f'Generated {n_samples} LHS samples across {len(param_names)} parameters')
print(f'Parameter names: {param_names}')
print(f'Sample shape: {samples.shape}')  # (n_samples, 15)
# Out:
# Generated 10 LHS samples across 3 parameters
# Parameter names: ['pressure', 'temperature', 'humidity']
# Sample shape: (10, 3)

# %%
# Wavelength range: 0.5 - 1.8 um
wavestart = 500.0   # nm
waveend = 1800.0    # nm

# Load wavelength grid from stellar spectra HDF5
stellar_h5 = Path('/home/mvasist/Documents/Tellurics/Phoenix/phoenix_spectra.h5')


with h5py.File(stellar_h5, 'r') as hf:
    stellar_wavegrid = hf['wavelengths'][0]  # (D,) — take first row since all are the same
    print(f'Stellar wavelength grid: {stellar_wavegrid.shape}')
    print(f'Range: {stellar_wavegrid.min():.4f} - {stellar_wavegrid.max():.4f} um')


modeler = Modeler()

transmission_list = []
labels_list = []
wavelength = None

for idx in range(n_samples):
    params = dict(zip(param_names, samples[idx]))
    
    if idx % 100 == 0:
        print(f'Generating model {idx+1}/{n_samples}')
    
    try:
        model = modeler.MakeModel(
            lowfreq=1e7 / waveend,
            highfreq=1e7 / wavestart,
            wavegrid=stellar_wavegrid,  # nm
            **params,
            **fixed_params,
        )
        
        if wavelength is None:
            wavelength = torch.tensor(model.x, dtype=torch.float32)
        
        transmission_list.append(torch.tensor(model.y, dtype=torch.float32))
        labels_list.append(torch.tensor(samples[idx], dtype=torch.float32))
        
    except Exception as e:
        print(f'  FAILED at {idx}: {e}')
        continue

print(f'\nSuccessfully generated {len(transmission_list)} models')


# Output path
outdir = Path('/home/mvasist/Documents/Tellurics/TelFit/telluric_templates')
outdir.mkdir(exist_ok=True)
CHUNKS_DIR = OUTDIR / "chunks"
CHUNKS_DIR.mkdir(exist_ok=True)
h5_path = CHUNKS_DIR / 'telluric_templates.h5'
# Out:
# Stellar wavelength grid: (19214,)
# Range: 500.0074 - 1799.9059 um
# Generating model 1/10
#
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 22.18user 2.72system 0:25.16elapsed 98%CPU (0avgtext+0avgdata 7680maxresident)k
# 88888inputs+2016928outputs (24major+1090minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 11.67user 2.55system 0:14.48elapsed 98%CPU (0avgtext+0avgdata 7808maxresident)k
# 3840inputs+1585920outputs (0major+1109minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 4.67user 1.90system 0:06.70elapsed 98%CPU (0avgtext+0avgdata 7552maxresident)k
# 904inputs+1190704outputs (1major+1100minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 3.46user 1.75system 0:05.35elapsed 97%CPU (0avgtext+0avgdata 7552maxresident)k
# 512inputs+1040528outputs (0major+1101minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 3.04user 1.74system 0:05.02elapsed 95%CPU (0avgtext+0avgdata 7808maxresident)k
# 512inputs+895096outputs (0major+1106minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 2.54user 1.61system 0:04.24elapsed 97%CPU (0avgtext+0avgdata 7680maxresident)k
# 240inputs+814680outputs (0major+1097minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 2.16user 1.62system 0:03.87elapsed 97%CPU (0avgtext+0avgdata 7552maxresident)k
# 0inputs+711224outputs (0major+1093minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 0.81user 1.07system 0:01.91elapsed 98%CPU (0avgtext+0avgdata 7552maxresident)k
# 0inputs+154336outputs (0major+1081minor)pagefaults 0swaps
# Warning, 34638 of 6020564 bins contained negative fluxes; they have been set to zero.
#   FAILED at 0: name 'torch' is not defined
#
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 21.91user 2.73system 0:25.64elapsed 96%CPU (0avgtext+0avgdata 7296maxresident)k
# 82832inputs+1985304outputs (0major+1107minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 10.35user 2.33system 0:14.15elapsed 89%CPU (0avgtext+0avgdata 7552maxresident)k
# 3840inputs+1486008outputs (0major+1100minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 4.67user 1.89system 0:06.80elapsed 96%CPU (0avgtext+0avgdata 7808maxresident)k
# 768inputs+1175752outputs (0major+1118minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 3.80user 1.80system 0:05.70elapsed 98%CPU (0avgtext+0avgdata 7808maxresident)k
# 512inputs+1019424outputs (0major+1101minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 2.93user 1.77system 0:04.82elapsed 97%CPU (0avgtext+0avgdata 7680maxresident)k
# 512inputs+931848outputs (0major+1100minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 2.01user 1.44system 0:03.50elapsed 98%CPU (0avgtext+0avgdata 7680maxresident)k
# 240inputs+781680outputs (0major+1099minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 2.25user 1.71system 0:04.19elapsed 94%CPU (0avgtext+0avgdata 7552maxresident)k
# 0inputs+696264outputs (0major+1090minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 0.85user 1.08system 0:01.96elapsed 98%CPU (0avgtext+0avgdata 7552maxresident)k
# 0inputs+150960outputs (0major+1079minor)pagefaults 0swaps
# Warning, 17805 of 5647305 bins contained negative fluxes; they have been set to zero.
#   FAILED at 1: name 'torch' is not defined
#
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 22.78user 2.92system 0:27.11elapsed 94%CPU (0avgtext+0avgdata 7296maxresident)k
# 79936inputs+2034320outputs (25major+1091minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 9.41user 2.19system 0:12.24elapsed 94%CPU (0avgtext+0avgdata 7680maxresident)k
# 2408inputs+1438712outputs (0major+1103minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 4.78user 2.13system 0:07.16elapsed 96%CPU (0avgtext+0avgdata 7808maxresident)k
# 720inputs+1171808outputs (0major+1102minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 4.32user 2.13system 0:06.95elapsed 92%CPU (0avgtext+0avgdata 7680maxresident)k
# 160inputs+1056272outputs (0major+1125minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 3.62user 2.33system 0:06.64elapsed 89%CPU (0avgtext+0avgdata 7552maxresident)k
# 38464inputs+919864outputs (10major+1104minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 3.09user 2.23system 0:05.96elapsed 89%CPU (0avgtext+0avgdata 7552maxresident)k
# 13000inputs+807304outputs (29major+1099minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 2.56user 2.24system 0:05.32elapsed 90%CPU (0avgtext+0avgdata 7040maxresident)k
# 190128inputs+700648outputs (27major+1082minor)pagefaults 0swaps
# Running exec: lblrtm
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# STOP  LBLRTM EXIT
# 0.90user 1.35system 0:02.44elapsed 92%CPU (0avgtext+0avgdata 6784maxresident)k
# 94472inputs+149040outputs (24major+1070minor)pagefaults 0swaps

# %%
# # Stack and save to HDF5
# transmission = torch.stack(transmission_list)  # (N, D)
# labels = torch.stack(labels_list)              # (N, n_params)

# print(f'Transmission shape: {transmission.shape}')
# print(f'Labels shape: {labels.shape}')
# print(f'Wavelength shape: {wavelength.shape}')

# with h5py.File(h5_path, 'w') as hf:
#     hf.create_dataset('wavelength', data=wavelength.numpy())         # (D,) — shared grid
#     hf.create_dataset('transmission', data=transmission.numpy())     # (N, D)
#     hf.create_dataset('labels', data=labels.numpy())                 # (N, n_params)
#     hf['labels'].attrs['columns'] = param_names
#     # Store fixed params as attributes for reproducibility
#     for k, v in fixed_params.items():
#         hf.attrs[f'fixed_{k}'] = v
#     hf.attrs['wavestart_nm'] = wavestart
#     hf.attrs['waveend_nm'] = waveend

# print(f'\nSaved to {h5_path}')

# %%
# Verify
import matplotlib.pyplot as plt

with h5py.File(h5_path, 'r') as hf:
    print('Datasets:', list(hf.keys()))
    print(f'  wavelength:   {hf["wavelength"].shape}')
    print(f'  transmission: {hf["transmission"].shape}')
    print(f'  labels:       {hf["labels"].shape}')
    print(f'  label columns: {list(hf["labels"].attrs["columns"])}')

    wl = hf['wavelength'][:]
    fig, ax = plt.subplots(1, 1, figsize=(12, 4))
    for i in np.random.choice(len(hf['transmission']), 5, replace=False):
        lbl = hf['labels'][i]
        ax.plot(wl, hf['transmission'][i], lw=0.5,
                label=f'H={lbl[3]:.0f}% T={lbl[1]:.0f}K P={lbl[0]:.0f}hPa z={lbl[2]:.0f}°')
    ax.set_xlabel('Wavelength (nm)')
    ax.set_ylabel('Transmission')
    ax.legend(fontsize='small')
    ax.set_title('Sample telluric models from grid')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## testing decimals

# %%
params_one = dict(zip(param_names, np.round(samples[0], 2).astype(float)))  # Use the first sample for testing
params_one_ = dict(zip(param_names, samples[0]))  # Use the first sample for testing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 params_one = dict(zip(param_names, np.round(samples[0], 2).astype(float)))  # Use the first sample for testing
#       2 params_one_ = dict(zip(param_names, samples[0]))  # Use the first sample for testing
#
# NameError: name 'param_names' is not defined

# %%
def get_stellar_wavegrid():
    """Load the stellar wavelength grid (in um)."""
    with h5py.File(STELLAR_H5, "r") as hf:
        return hf["wavelengths"][0].astype(np.float32)  # (D,) in um

    # with h5py.File(STELLAR_H5, "r") as hf:
    #     print(list(hf.keys()))
    #     print(hf["wavelengths"][:].shape)
    #     print(hf["flux"][:].shape)
    #     print(hf["labels"][:].shape)
    #     print(hf["labels"].attrs["columns"])

    # return hf["wavelengths"][:].astype(np.float32)  # (D,) in um


# Load stellar wavegrid
stellar_wavegrid_nm = get_stellar_wavegrid()

print(stellar_wavegrid_nm.shape, " see this first")

# %%
params_one, params_one_

# %%
stellar_wavegrid_nm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 stellar_wavegrid_nm
#
# NameError: name 'stellar_wavegrid_nm' is not defined

# %%
m = Modeler()
start = time.time()
model = m.MakeModel(lowfreq=1e7/1800, highfreq=1e7/500, \
                    wavegrid=stellar_wavegrid_nm, **FIXED_PARAMS, **params_one) 
print(f'OK: {len(model.x)} points')
end = time.time()

print(f'Model time: {end-start}')

plt.plot(model.x, model.y)
plt.show()

# %% [markdown]
# ## Adding
